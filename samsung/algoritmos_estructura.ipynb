# %%
# Algoritmos de Ordenamiento en Python

# 1. Ordenamiento Burbuja (Bubble Sort)
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

# Prueba Bubble Sort
arr_bubble = [64, 34, 25, 12, 22, 11, 90]
print("Bubble Sort:", bubble_sort(arr_bubble.copy()))

# 2. Ordenamiento por Inserción (Insertion Sort)
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >=0 and key < arr[j]:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key
    return arr

# Prueba Insertion Sort
arr_insertion = [64, 34, 25, 12, 22, 11, 90]
print("Insertion Sort:", insertion_sort(arr_insertion.copy()))

# 3. Ordenamiento por Selección (Selection Sort)
def selection_sort(arr):
    for i in range(len(arr)):
        min_idx = i
        for j in range(i+1, len(arr)):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

# Prueba Selection Sort
arr_selection = [64, 34, 25, 12, 22, 11, 90]
print("Selection Sort:", selection_sort(arr_selection.copy()))

# 4. Merge Sort
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr)//2
        L = arr[:mid]
        R = arr[mid:]

        merge_sort(L)
        merge_sort(R)

        i = j = k = 0

        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1
    return arr

# Prueba Merge Sort
arr_merge = [64, 34, 25, 12, 22, 11, 90]
print("Merge Sort:", merge_sort(arr_merge.copy()))
# Out:
# Bubble Sort: [11, 12, 22, 25, 34, 64, 90]
# Insertion Sort: [11, 12, 22, 25, 34, 64, 90]
# Selection Sort: [11, 12, 22, 25, 34, 64, 90]
# Merge Sort: [11, 12, 22, 25, 34, 64, 90]
